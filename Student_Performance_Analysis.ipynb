# %% [markdown]
# #Student_Performance_Analysis
# ## Objectives
# This project explores the factors that influence student performance using Python and Pandas. The aim is to clean the dataset, perform exploratory data analysis, create visualisations and identidy patterns that may contribute to improve educational outcomes.

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/Users/jessicankosi'

# %%
os.listdir()
# Out:
# ['.config',
#  'Music',
#  '.zprofile.pysave',
#  '.copilot',
#  '.DS_Store',
#  '.vscode-shared',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  '.zshrc',
#  'OneDrive',
#  '.psql_history',
#  'Pictures',
#  '.zprofile',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'Zotero',
#  '.pgadmin',
#  '.cups',
#  'PycharmProjects',
#  'Public',
#  '.idlerc',
#  '.tcshrc',
#  '.anaconda',
#  'Movies',
#  'Applications',
#  '.Trash',
#  'Student_Performance_Analysis.ipynb',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'Documents',
#  '.vscode',
#  '.bash_profile',
#  'Downloads',
#  '.python_history',
#  '.continuum',
#  '.zsh_sessions',
#  '.conda',
#  'PyCharmMiscProject']

# %%
os.listdir("Desktop")
# Out:
# ['Jessica Nkosi',
#  'School Policies',
#  '6B311217-3B5C-4B3B-872E-0BA9CB193D5B.PNG',
#  '.DS_Store',
#  '.localized',
#  '~$4774836_2025 WSG Assessment template.docx',
#  'Forest Hill Primary  ',
#  'StudentPerformanceFactors.csv',
#  'National School of Governance ',
#  'Mnumzane Ndlela ',
#  '~$DESCRIPTIVE ESSAY PRESENTATION.pptx',
#  'ZAIO',
#  'High_DA21248-060.jpg',
#  'Screenshot 2026-07-16 at 12.14.08.png',
#  '~$& M GR 7.docx',
#  '.ipynb_checkpoints',
#  'CODING ',
#  'desktop.ini',
#  'FNB ACADEMY',
#  'WITS SCHOOL OF GOVERNANCE ']

# %%
df = pd.read_csv("Desktop/StudentPerformanceFactors.csv", sep=";")

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
#Exploring the Dataset

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Observation
#- Dataset contains 6,607 observations and 20 variables.
#-There are 7 numerical columns and 13 categorical columns
#-Three columns that contain missing vallue:
# Teacher_Quality(78)
#Parental_Education_Level(90)
# Distance_from_home(67)
#-There are no duplicate records.
#The average score is approximately 67
#Students study about 20 hours on average and sleep 7 hours

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df)) *100

pd.DataFrame({
    "Missing Values": missing,
    "Percentage": missing_percent
})
# Out:
#                             Missing Values  Percentage
# Hours_Studied                            0    0.000000
# Attendance                               0    0.000000
# Parental_Involvement                     0    0.000000
# Access_to_Resources                      0    0.000000
# Extracurricular_Activities               0    0.000000
# Sleep_Hours                              0    0.000000
# Previous_Scores                          0    0.000000
# Motivation_Level                         0    0.000000
# Internet_Access                          0    0.000000
# Tutoring_Sessions                        0    0.000000
# Family_Income                            0    0.000000
# Teacher_Quality                         78    1.180566
# School_Type                              0    0.000000
# Peer_Influence                           0    0.000000
# Physical_Activity                        0    0.000000
# Learning_Disabilities                    0    0.000000
# ...

# %%
df = df.dropna()

# %% [markdown]
# df.isnull().sum()

# %%
df["Teacher_Quality"].value_counts()
# Out:
# Teacher_Quality
# Medium    3826
# High      1905
# Low        647
# Name: count, dtype: int64

# %%
df["School_Type"].value_counts()
df["Gender"].value_counts()
df["Internet_Access"].value_counts()
df["Motivation_Level"].value_counts()
# Out:
# Motivation_Level
# Medium    3237
# Low       1864
# High      1277
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6378.000000  6378.000000  6378.000000      6378.000000
# mean       19.977109    80.020853     7.034964        75.066165
# std         5.985460    11.550723     1.468033        14.400389
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6378.000000        6378.000000  6378.000000
# mean            1.495296           2.972719    67.252117
# std             1.233984           1.028926     3.914217
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
df["Exam_Score"].hist()

plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")
plt.show()

# %%
#Observation
#- The dataset contains 6,607 student records and 20 variables
#- There are no duplicate records
#A few columns (3) contains missing values
#- Most exams marks are between 60 and 70
